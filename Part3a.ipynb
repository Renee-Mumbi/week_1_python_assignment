# %%
import pandas

# %%
import requests

# %%
products_url = "https://dummyjson.com/products"

# %%
products_content = requests.get(products_url)

# %%
product_set = products_content.json()
type(product_set)
# Out:
# dict

# %%
product_list = list(product_set)

# %%
type(product_list)
# Out:
# list

# %%
lists = product_list [:100]

# %%
df = pandas.DataFrame(lists)

# %%
df.head(5)
# Out:
#           0
# 0  products
# 1     total
# 2      skip
# 3     limit

# %%
df.to_csv("product_list.csv")
