# %%
import pandas

# %%
import requests

# %%
staff_url="https://raw.githubusercontent.com/Renee-Mumbi/assignment1_python/refs/heads/main/staff_data.json"

# %%
staff_content = requests.get(staff_url)

# %%
staff_data = staff_content.json()
type(staff_data)
# Out:
# list

# %%
sample = staff_data[:100]

# %%
df = pandas.DataFrame(sample)

# %%
df.head(5)
# Out:
#   first_name last_name     salary department
# 0        Den      Want  103314.65  Marketing
# 1        Web    Laflin   54167.38  Marketing
# 2      Tasia     Fyers   44628.09      Sales
# 3      Leona  Trippett   46796.12  Marketing
# 4      Grace     Arndt  109962.84         IT

# %%
df.to_csv("staff_data.csv")
